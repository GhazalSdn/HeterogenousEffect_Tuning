# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from CTL.causal_tree_learn import CausalTree
import numpy as np
import pickle

# %%
print("### Load Data ######################")
data = pd.read_csv('data/preprocessed_app_data.csv')
data
# Out:
# ### Load Data ######################
#       spark.executor.cores  spark.executor.memory  spark.default.parallelism  \
# 0                        7                      6                         29
# 1                        7                      6                         37
# 2                        6                      6                         16
# 3                        6                      7                         31
# 4                        5                      1                         10
# ...                    ...                    ...                        ...
# 1890                     4                      7                         27
# 1891                     2                     11                         49
# 1892                     5                      9                         40
# 1893                     5                      6                         15
# 1894                     6                      9                          8
#
#       spark.serializer  spark.task.cpus  executorDeserializeCpuTime  \
# 0                    0                2                5.275688e+07
# 1                    0                1                5.040701e+07
# 2                    1                2                5.691199e+07
# 3                    0                2                6.257915e+07
# 4                    1                2                5.772729e+07
# ...                ...              ...                         ...
# 1890                 1                2                4.732003e+07
# 1891                 0                2                7.046542e+07
# 1892                 1                2                4.930322e+07
# 1893                 1                1                5.672639e+07
# 1894                 1                1                5.839340e+07
#
#       executorRunTime  executorCpuTime  resultSize  jvmGcTime  Execution_Time
# 0            881.7425     5.304603e+08   1133.1900   251.3500           40424
# 1           1364.3075     5.896709e+08   1141.0900   234.2000           39742
# 2            852.4075     5.437210e+08   1302.3825   205.3500           41370
# 3            849.0325     5.488717e+08   1137.8575   219.5600           42098
# 4           7255.6350     3.820878e+09   1318.9675  1025.0025          384288
# ...               ...              ...         ...        ...             ...
# 1890         745.8075     5.019402e+08   1303.0100   160.0950           46745
# 1891         539.5075     5.022112e+08   1134.4225    60.6725           66769
# 1892         664.5925     5.126925e+08   1301.2625   109.7975           50925
# 1893        1054.0925     5.442330e+08   1307.7225   259.0050           37600
# 1894         968.7350     5.780306e+08   1361.7025   226.9175           32395
#
# [1895 rows x 11 columns]

# %%
# columns = ['spark.executor.cores', 
#            'spark.executor.memory',
#            'spark.default.parallelism', 
#            'spark.serializer', 
#            'spark.task.cpus',
#            'executorDeserializeCpuTime', 
#            'executorRunTime', 
#            'executorCpuTime',
#            'resultSize', 
#            'jvmGcTime', 
#            'Execution_Time']
treatment_col = 'spark.executor.cores'

# %%
data1 = data
data2 = data.sample(n=len(data), replace=True)
data3 = data.sample(n=len(data), replace=True)

# %%
data1.describe()
# Out:
#        spark.executor.cores  spark.executor.memory  spark.default.parallelism  \
# count           1895.000000            1895.000000                1895.000000
# mean               4.173087               6.586807                  29.033773
# std                1.884639               3.500299                  12.356758
# min                1.000000               1.000000                   8.000000
# 25%                3.000000               3.000000                  19.000000
# 50%                4.000000               7.000000                  29.000000
# 75%                6.000000              10.000000                  39.000000
# max                7.000000              12.000000                  50.000000
#
#        spark.serializer  spark.task.cpus  executorDeserializeCpuTime  \
# count       1895.000000      1895.000000                1.895000e+03
# mean           0.486016         1.509763                6.361890e+07
# std            0.499936         0.500037                3.799322e+07
# min            0.000000         1.000000                1.311662e+07
# 25%            0.000000         1.000000                4.928798e+07
# 50%            0.000000         2.000000                5.503954e+07
# 75%            1.000000         2.000000                6.794721e+07
# max            1.000000         2.000000                1.363984e+09
#
#        executorRunTime  executorCpuTime   resultSize    jvmGcTime  \
# count      1895.000000     1.895000e+03  1895.000000  1895.000000
# mean       2087.056219     7.866544e+08  1219.653930   249.924603
# std        3103.665027     8.267756e+08    87.363377   305.147189
# min         514.177500     4.685354e+08   896.500000    45.652500
# 25%         787.188750     5.179380e+08  1134.137500   123.472500
# 50%        1024.972500     5.373583e+08  1164.040000   187.480000
# 75%        1556.551250     5.701036e+08  1305.586250   238.805000
# max       28424.285000     4.695917e+09  1373.730000  2623.227500
#
#        Execution_Time
# count     1895.000000
# mean     91791.294987
# std     102767.662478
# min      29045.000000
# 25%      42699.500000
# 50%      53553.000000
# 75%      78356.000000
# max     792493.000000

# %%
data2.describe()
# Out:
#        spark.executor.cores  spark.executor.memory  spark.default.parallelism  \
# count           1895.000000            1895.000000                1895.000000
# mean               4.169921               6.599472                  29.028496
# std                1.853574               3.546419                  12.300240
# min                1.000000               1.000000                   8.000000
# 25%                3.000000               3.000000                  19.000000
# 50%                4.000000               7.000000                  29.000000
# 75%                6.000000              10.000000                  39.000000
# max                7.000000              12.000000                  50.000000
#
#        spark.serializer  spark.task.cpus  executorDeserializeCpuTime  \
# count       1895.000000      1895.000000                1.895000e+03
# mean           0.493404         1.489710                6.470020e+07
# std            0.500088         0.500026                5.687642e+07
# min            0.000000         1.000000                3.306553e+07
# 25%            0.000000         1.000000                4.906657e+07
# 50%            0.000000         1.000000                5.464265e+07
# 75%            1.000000         2.000000                6.797352e+07
# max            1.000000         2.000000                1.363984e+09
#
#        executorRunTime  executorCpuTime   resultSize    jvmGcTime  \
# count      1895.000000     1.895000e+03  1895.000000  1895.000000
# mean       2184.834301     8.217736e+08  1220.227203   266.120625
# std        3275.375169     8.910956e+08    87.466558   336.434720
# min         522.875000     4.685354e+08   896.500000    49.037500
# 25%         790.027500     5.179380e+08  1134.357500   127.967500
# 50%        1055.530000     5.380951e+08  1170.467500   192.382500
# 75%        1600.100000     5.707729e+08  1305.178750   243.011250
# max       28424.285000     4.695917e+09  1368.325000  2623.227500
#
#        Execution_Time
# count     1895.000000
# mean     92944.829024
# std     104491.808814
# min      29421.000000
# 25%      42699.500000
# 50%      53135.000000
# 75%      79361.500000
# max     792493.000000

# %%
data3.describe()
# Out:
#        spark.executor.cores  spark.executor.memory  spark.default.parallelism  \
# count           1895.000000            1895.000000                1895.000000
# mean               4.174670               6.578364                  29.020580
# std                1.883231               3.494460                  12.414144
# min                1.000000               1.000000                   8.000000
# 25%                3.000000               3.000000                  19.000000
# 50%                4.000000               7.000000                  29.000000
# 75%                6.000000              10.000000                  39.000000
# max                7.000000              12.000000                  50.000000
#
#        spark.serializer  spark.task.cpus  executorDeserializeCpuTime  \
# count       1895.000000      1895.000000                1.895000e+03
# mean           0.469129         1.501847                6.402154e+07
# std            0.499178         0.500129                3.780642e+07
# min            0.000000         1.000000                1.311662e+07
# 25%            0.000000         1.000000                4.960289e+07
# 50%            0.000000         2.000000                5.601869e+07
# 75%            1.000000         2.000000                6.804447e+07
# max            1.000000         2.000000                1.363984e+09
#
#        executorRunTime  executorCpuTime   resultSize    jvmGcTime  \
# count      1895.000000     1.895000e+03  1895.000000  1895.000000
# mean       2062.230048     7.944811e+08  1216.755994   251.486360
# std        3042.478418     8.462098e+08    87.582526   308.228213
# min         514.177500     4.685354e+08   896.500000    45.652500
# 25%         787.297500     5.183767e+08  1133.240000   124.546250
# 50%        1017.565000     5.381689e+08  1151.955000   187.185000
# 75%        1514.347500     5.699476e+08  1305.310000   236.075000
# max       28424.285000     4.695917e+09  1373.730000  2536.722500
#
#        Execution_Time
# count     1895.000000
# mean     91415.277045
# std     101814.678939
# min      29045.000000
# 25%      42091.500000
# 50%      53368.000000
# 75%      76300.000000
# max     792493.000000

# %%
y1 = data1['Execution_Time'].values
treat1 = data1[treatment_col].values
# # other configs
drop_cols = ['Execution_Time', #Outcome
             treatment_col, #Treatment
             'executorDeserializeCpuTime', 'executorRunTime', 'executorCpuTime', 'resultSize', 'jvmGcTime' # mediators
            ]
x1 = data1.drop(drop_cols, axis=1).values
columns = data1.drop(drop_cols, axis=1).columns

# %%
y2 = data2['Execution_Time'].values
treat2 = data2[treatment_col].values
# # other configs
drop_cols = ['Execution_Time', #Outcome
             treatment_col, #Treatment
             'executorDeserializeCpuTime', 'executorRunTime', 'executorCpuTime', 'resultSize', 'jvmGcTime' # mediators
            ]
x2 = data2.drop(drop_cols, axis=1).values
columns = data2.drop(drop_cols, axis=1).columns

# %%
y3 = data3['Execution_Time'].values
treat3 = data3[treatment_col].values
# # other configs
drop_cols = ['Execution_Time', #Outcome
             treatment_col, #Treatment
             'executorDeserializeCpuTime', 'executorRunTime', 'executorCpuTime', 'resultSize', 'jvmGcTime' # mediators
            ]
x3 = data3.drop(drop_cols, axis=1).values
columns = data3.drop(drop_cols, axis=1).columns

# %%
np.random.seed(0)

# %%
# x1, x2, y1, y2, treat1, treat2 = train_test_split(x, y, treatment, test_size=0.5, random_state=5)

# %% [markdown]
# # Part 1

# %%
x1_train, x1_test, y1_train, y1_test, treat1_train, treat1_test = train_test_split(x1, y1, treat1, test_size=0.2, random_state=42)

# %%
# regular CTL
ctl = CausalTree(cont=True)
ctl.fit(x1_train, y1_train, treat1_train)
ctl.prune()
ctl_predict = ctl.predict(x1_test)

# honest CTL
cth = CausalTree(cont=True, honest=True)
cth.fit(x1_train, y1_train, treat1_train)
cth.prune()
cth_predict = cth.predict(x1_test)

# val honest CTL
cthv = CausalTree(cont=True, val_honest=True)
cthv.fit(x1_train, y1_train, treat1_train)
cthv.prune()
cthv_predict1 = cthv.predict(x1_test)

# adaptive CT
ct_adaptive = CausalTree(weight=0.0, split_size=0.0, cont=True)
ct_adaptive.fit(x1_train, y1_train, treat1_train)
ct_adaptive.prune()
ct_adaptive_predict = ct_adaptive.predict(x1_test)

# honest CT
ct_honest = CausalTree(honest=True, weight=0.0, split_size=0.0, cont=True)
ct_honest.fit(x1_train, y1_train, treat1_train)
ct_honest.prune()
ct_honest_predict = ct_honest.predict(x1_test)


# if you want to plot a tree

# ct_adaptive.plot_tree(features=columns, filename="output/p_otherConfigs_cores/adaptive_ct_otherF", show_effect=True)
# ct_honest.plot_tree(features=columns, filename="output/p_otherConfigs_cores/honest_ct_otherF", show_effect=True)
# ctl.plot_tree(features=columns, filename="output/p_otherConfigs_cores/regular_ctl_otherF", show_effect=True)
# cth.plot_tree(features=columns, filename="output/p_otherConfigs_cores/honest_ctl_otherF", show_effect=True)
# cthv.plot_tree(features=columns, filename="output/p_otherConfigs_cores/valHonest_ctl_otherF", show_effect=True)


ct_adaptive.plot_tree(features=columns, filename="output/robust_p_otherConfigs_cores/1adaptive_ct_otherF", show_effect=True)
ct_honest.plot_tree(features=columns, filename="output/robust_p_otherConfigs_cores/1honest_ct_otherF", show_effect=True)
ctl.plot_tree(features=columns, filename="output/robust_p_otherConfigs_cores/1regular_ctl_otherF", show_effect=True)
cth.plot_tree(features=columns, filename="output/robust_p_otherConfigs_cores/1honest_ctl_otherF", show_effect=True)
cthv.plot_tree(features=columns, filename="output/robust_p_otherConfigs_cores/1valHonest_ctl_otherF", show_effect=True)


# ct_adaptive.plot_tree(features=columns, filename="output/robust_p_otherConfigs_cores/1adaptive_ct_otherF", show_effect=True)
# ct_honest.plot_tree(features=columns, filename="output/robust_p_otherConfigs_cores/1honest_ct_otherF", show_effect=True)
# ctl.plot_tree(features=columns, filename="output/robust_p_otherConfigs_cores/1regular_ctl_otherF", show_effect=True)
# cth.plot_tree(features=columns, filename="output/robust_p_otherConfigs_cores/1honest_ctl_otherF", show_effect=True)
# cthv.plot_tree(features=columns, filename="output/robust_p_otherConfigs_cores/1valHonest_ctl_otherF", show_effect=True)

# ct_adaptive.plot_tree(features=columns, filename="output/otherConfigs_parallelism/parallelism_adaptive_ct_otherF", show_effect=True)
# ct_honest.plot_tree(features=columns, filename="output/otherConfigs_parallelism/parallelism_honest_ct_otherF", show_effect=True)
# ctl.plot_tree(features=columns, filename="output/otherConfigs_parallelism/parallelism_regular_ctl_otherF", show_effect=True)
# cth.plot_tree(features=columns, filename="output/otherConfigs_parallelism/parallelism_honest_ctl_otherF", show_effect=True)
# cthv.plot_tree(features=columns, filename="output/otherConfigs_parallelism/parallelism_valHonest_ctl_otherF", show_effect=True)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3723: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:254: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
cthv.get_variables_used(columns)
# Out:
# ['spark.executor.memory', 'spark.task.cpus', 'spark.default.parallelism']

# %%
cthv_predict1
# Out:
# array([-29081.94610592, -47405.29166667, -25963.16039973, -29081.94610592,
#        -29081.94610592, -29081.94610592, -12726.16666667, -29081.94610592,
#        -29081.94610592, -29081.94610592, -29081.94610592, 192428.88888889,
#        -29081.94610592, -29081.94610592, -24922.9965035 , -25963.16039973,
#        -29081.94610592, -29081.94610592, -29081.94610592, -25963.16039973,
#        -25963.16039973, -29081.94610592, -25963.16039973, -22771.91666667,
#        -29081.94610592, -29081.94610592, -25963.16039973, 182392.25      ,
#        -29081.94610592, -25963.16039973, -24922.9965035 , -29081.94610592,
#         82450.25      , -25963.16039973, -25963.16039973, -29081.94610592,
#        -29081.94610592, -25963.16039973, -29081.94610592, -29081.94610592,
#        -29081.94610592, -29081.94610592, -47405.29166667, -29081.94610592,
#        -29081.94610592, -29081.94610592, -22771.91666667, -25963.16039973,
#        -29081.94610592, -25963.16039973, -25963.16039973, -29081.94610592,
#        -29081.94610592, -29081.94610592, -29081.94610592, -29081.94610592,
#        -25963.16039973, 182392.25      , -29081.94610592, 233155.5       ,
#        -12726.16666667, 182392.25      , -25963.16039973, -29081.94610592,
#          4114.66666667, -12726.16666667, -25963.16039973, 182392.25      ,
#        -22771.91666667, -25963.16039973, 182392.25      , -29081.94610592,
#        -24922.9965035 , -25963.16039973, 182392.25      , -29081.94610592,
#        -12726.16666667, -25963.16039973, -25963.16039973,  82450.25      ,
#        -29081.94610592, -29081.94610592, -29081.94610592, -24922.9965035 ,
#        -25963.16039973, -29081.94610592, -24922.9965035 , -31747.75      ,
#        -25963.16039973, -47405.29166667, 192428.88888889, 192428.88888889,
#         62912.375     , -29081.94610592, 182392.25      ,  82450.25      ,
#        -25963.16039973, -47405.29166667, -29081.94610592, -29081.94610592,
#        -29081.94610592, -29081.94610592,  82450.25      , -12726.16666667,
#        -24922.9965035 , -25963.16039973, -29081.94610592, -29081.94610592,
#        -24922.9965035 , -24922.9965035 , -29081.94610592, -25963.16039973,
#        182392.25      , -22771.91666667, 233155.5       , -29081.94610592,
#        -25963.16039973, -25963.16039973, -29081.94610592, -25963.16039973,
#        -24922.9965035 ,  82450.25      , -29081.94610592, -25963.16039973,
#        -25963.16039973, 182392.25      , -29081.94610592, -47405.29166667,
#        -22771.91666667, -29081.94610592, -25963.16039973, -25963.16039973,
#        -29081.94610592, -29081.94610592, -25963.16039973, -25963.16039973,
#         62912.375     , -25963.16039973, 233155.5       , -47405.29166667,
#        -24922.9965035 , -29081.94610592, -25963.16039973, -29081.94610592,
#        182392.25      ,  82450.25      , 182392.25      , -29081.94610592,
#        -25963.16039973, -29081.94610592, -47405.29166667, -29081.94610592,
#        -31747.75      , -25963.16039973, -29081.94610592, -25963.16039973,
#        -25963.16039973, -22771.91666667, -29081.94610592, -47405.29166667,
#        -29081.94610592, -25963.16039973, -24922.9965035 ,   4114.66666667,
#         82450.25      , -25963.16039973, 182392.25      , -29081.94610592,
#        -29081.94610592,  82450.25      , -24922.9965035 , -24922.9965035 ,
#        -29081.94610592, -29081.94610592, -31747.75      , 182392.25      ,
#        -29081.94610592, 233155.5       , -29081.94610592, -31747.75      ,
#        -25963.16039973, -29081.94610592, 182392.25      , -29081.94610592,
#        -25963.16039973, -29081.94610592, -24922.9965035 , -25963.16039973,
#        -29081.94610592, -29081.94610592, -29081.94610592, -12726.16666667,
#        -25963.16039973,  82450.25      , -29081.94610592, -29081.94610592,
#        -29081.94610592, -25963.16039973, 182392.25      , -29081.94610592,
#        -22771.91666667, -25963.16039973,  62912.375     , -29081.94610592,
#        -31747.75      , -22771.91666667,  62912.375     , -24922.9965035 ,
#        -29081.94610592, -25963.16039973, -12726.16666667, -25963.16039973,
#        -29081.94610592, -29081.94610592, -25963.16039973, -29081.94610592,
#        -25963.16039973, -25963.16039973, 192428.88888889, -25963.16039973,
#        -25963.16039973, -29081.94610592, -29081.94610592,  82450.25      ,
#        -29081.94610592, -29081.94610592, -29081.94610592, -29081.94610592,
#        -29081.94610592, -12726.16666667, -29081.94610592, -25963.16039973,
#         62912.375     , -24922.9965035 , -29081.94610592, -29081.94610592,
#        -29081.94610592, -22771.91666667, -25963.16039973, 182392.25      ,
#        182392.25      , -25963.16039973, -29081.94610592, -25963.16039973,
#        -29081.94610592, -25963.16039973, 192428.88888889, -29081.94610592,
#        -24922.9965035 , -25963.16039973, -24922.9965035 , -29081.94610592,
#        182392.25      , -29081.94610592, 182392.25      , -29081.94610592,
#        -22771.91666667, -29081.94610592, -29081.94610592, -25963.16039973,
#        -25963.16039973,  62912.375     , -22771.91666667, -29081.94610592,
#        -29081.94610592, -25963.16039973,  82450.25      , -29081.94610592,
#        -25963.16039973, -29081.94610592, -47405.29166667, -24922.9965035 ,
#        -47405.29166667, -22771.91666667, -29081.94610592,   4114.66666667,
#        -29081.94610592, -47405.29166667, -25963.16039973, -29081.94610592,
#        -29081.94610592, -29081.94610592, -24922.9965035 , -12726.16666667,
#        -29081.94610592, -12726.16666667, -25963.16039973, -29081.94610592,
#        -24922.9965035 , -29081.94610592,  62912.375     , -29081.94610592,
#        -29081.94610592, -29081.94610592, -29081.94610592, -25963.16039973,
#        -29081.94610592, -25963.16039973, -25963.16039973, -29081.94610592,
#        -29081.94610592, -25963.16039973, -29081.94610592,  82450.25      ,
#        -25963.16039973, -22771.91666667, -29081.94610592, -25963.16039973,
#        -25963.16039973, -25963.16039973, -29081.94610592, 182392.25      ,
#        -29081.94610592, -29081.94610592, -29081.94610592, -25963.16039973,
#        -19220.66666667, -24922.9965035 , -25963.16039973, -25963.16039973,
#        233155.5       , -29081.94610592, -25963.16039973, -25963.16039973,
#        -22771.91666667, -29081.94610592, -25963.16039973, -25963.16039973,
#        -29081.94610592, -25963.16039973, -29081.94610592, -29081.94610592,
#        -12726.16666667, -29081.94610592, -25963.16039973, -25963.16039973,
#        -25963.16039973, -25963.16039973, 182392.25      ,  82450.25      ,
#        -29081.94610592, -29081.94610592, -25963.16039973, -29081.94610592,
#        -12726.16666667, -25963.16039973, -25963.16039973, 192428.88888889,
#        -22771.91666667, -29081.94610592, -25963.16039973, -24922.9965035 ,
#        -25963.16039973, -29081.94610592, -24922.9965035 , -25963.16039973,
#        -29081.94610592, -25963.16039973, -31747.75      , -29081.94610592,
#        -24922.9965035 , -25963.16039973, -25963.16039973, -25963.16039973,
#        -12726.16666667, -22771.91666667, -31747.75      , -22771.91666667,
#        -29081.94610592, -29081.94610592, -29081.94610592, -29081.94610592,
#        -29081.94610592, -25963.16039973, -29081.94610592, -29081.94610592,
#        182392.25      , -25963.16039973, 233155.5       ])

# %% [markdown]
# # Part 2

# %%
x2_train, x2_test, y2_train, y2_test, treat2_train, treat2_test = train_test_split(x2, y2, treat2, test_size=0.2, random_state=42)

# %%
# regular CTL
ctl = CausalTree(cont=True)
ctl.fit(x2_train, y2_train, treat2_train)
ctl.prune()
ctl_predict = ctl.predict(x2_test)

# honest CTL
cth = CausalTree(cont=True, honest=True)
cth.fit(x2_train, y2_train, treat2_train)
cth.prune()
cth_predict = cth.predict(x2_test)

# val honest CTL
cthv = CausalTree(cont=True, val_honest=True)
cthv.fit(x2_train, y2_train, treat2_train)
cthv.prune()
cthv_predict2 = cthv.predict(x1_test)

# adaptive CT
ct_adaptive = CausalTree(weight=0.0, split_size=0.0, cont=True)
ct_adaptive.fit(x2_train, y2_train, treat2_train)
ct_adaptive.prune()
ct_adaptive_predict = ct_adaptive.predict(x2_test)

# honest CT
ct_honest = CausalTree(honest=True, weight=0.0, split_size=0.0, cont=True)
ct_honest.fit(x2_train, y2_train, treat2_train)
ct_honest.prune()
ct_honest_predict = ct_honest.predict(x2_test)


# if you want to plot a tree

# ct_adaptive.plot_tree(features=columns, filename="output/p_otherConfigs_cores/adaptive_ct_otherF", show_effect=True)
# ct_honest.plot_tree(features=columns, filename="output/p_otherConfigs_cores/honest_ct_otherF", show_effect=True)
# ctl.plot_tree(features=columns, filename="output/p_otherConfigs_cores/regular_ctl_otherF", show_effect=True)
# cth.plot_tree(features=columns, filename="output/p_otherConfigs_cores/honest_ctl_otherF", show_effect=True)
# cthv.plot_tree(features=columns, filename="output/p_otherConfigs_cores/valHonest_ctl_otherF", show_effect=True)


ct_adaptive.plot_tree(features=columns, filename="output/robust_p_otherConfigs_cores/2adaptive_ct_otherF", show_effect=True)
ct_honest.plot_tree(features=columns, filename="output/robust_p_otherConfigs_cores/2honest_ct_otherF", show_effect=True)
ctl.plot_tree(features=columns, filename="output/robust_p_otherConfigs_cores/2regular_ctl_otherF", show_effect=True)
cth.plot_tree(features=columns, filename="output/robust_p_otherConfigs_cores/2honest_ctl_otherF", show_effect=True)
cthv.plot_tree(features=columns, filename="output/robust_p_otherConfigs_cores/2valHonest_ctl_otherF", show_effect=True)

# ct_adaptive.plot_tree(features=columns, filename="output/otherConfigs_parallelism/parallelism_adaptive_ct_otherF", show_effect=True)
# ct_honest.plot_tree(features=columns, filename="output/otherConfigs_parallelism/parallelism_honest_ct_otherF", show_effect=True)
# ctl.plot_tree(features=columns, filename="output/otherConfigs_parallelism/parallelism_regular_ctl_otherF", show_effect=True)
# cth.plot_tree(features=columns, filename="output/otherConfigs_parallelism/parallelism_honest_ctl_otherF", show_effect=True)
# cthv.plot_tree(features=columns, filename="output/otherConfigs_parallelism/parallelism_valHonest_ctl_otherF", show_effect=True)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3723: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:254: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
cthv.get_variables_used(columns)
# Out:
# ['spark.executor.memory',
#  'spark.default.parallelism',
#  'spark.task.cpus',
#  'spark.serializer']

# %% [markdown]
# # Part 3

# %%
x3_train, x3_test, y3_train, y3_test, treat3_train, treat3_test = train_test_split(x3, y3, treat3, test_size=0.2, random_state=42)

# %%
# regular CTL
ctl = CausalTree(cont=True)
ctl.fit(x3_train, y3_train, treat3_train)
ctl.prune()
ctl_predict = ctl.predict(x3_test)

# honest CTL
cth = CausalTree(cont=True, honest=True)
cth.fit(x3_train, y3_train, treat3_train)
cth.prune()
cth_predict = cth.predict(x3_test)

# val honest CTL
cthv = CausalTree(cont=True, val_honest=True)
cthv.fit(x3_train, y3_train, treat3_train)
cthv.prune()
cthv_predict3 = cthv.predict(x1_test)

# adaptive CT
ct_adaptive = CausalTree(weight=0.0, split_size=0.0, cont=True)
ct_adaptive.fit(x3_train, y3_train, treat3_train)
ct_adaptive.prune()
ct_adaptive_predict = ct_adaptive.predict(x3_test)

# honest CT
ct_honest = CausalTree(honest=True, weight=0.0, split_size=0.0, cont=True)
ct_honest.fit(x3_train, y3_train, treat3_train)
ct_honest.prune()
ct_honest_predict = ct_honest.predict(x3_test)


# if you want to plot a tree

# ct_adaptive.plot_tree(features=columns, filename="output/p_otherConfigs_cores/adaptive_ct_otherF", show_effect=True)
# ct_honest.plot_tree(features=columns, filename="output/p_otherConfigs_cores/honest_ct_otherF", show_effect=True)
# ctl.plot_tree(features=columns, filename="output/p_otherConfigs_cores/regular_ctl_otherF", show_effect=True)
# cth.plot_tree(features=columns, filename="output/p_otherConfigs_cores/honest_ctl_otherF", show_effect=True)
# cthv.plot_tree(features=columns, filename="output/p_otherConfigs_cores/valHonest_ctl_otherF", show_effect=True)


ct_adaptive.plot_tree(features=columns, filename="output/robust_p_otherConfigs_cores/3adaptive_ct_otherF", show_effect=True)
ct_honest.plot_tree(features=columns, filename="output/robust_p_otherConfigs_cores/3honest_ct_otherF", show_effect=True)
ctl.plot_tree(features=columns, filename="output/robust_p_otherConfigs_cores/3regular_ctl_otherF", show_effect=True)
cth.plot_tree(features=columns, filename="output/robust_p_otherConfigs_cores/3honest_ctl_otherF", show_effect=True)
cthv.plot_tree(features=columns, filename="output/robust_p_otherConfigs_cores/3valHonest_ctl_otherF", show_effect=True)


# ct_adaptive.plot_tree(features=columns, filename="output/robust_p_otherConfigs_cores/1adaptive_ct_otherF", show_effect=True)
# ct_honest.plot_tree(features=columns, filename="output/robust_p_otherConfigs_cores/1honest_ct_otherF", show_effect=True)
# ctl.plot_tree(features=columns, filename="output/robust_p_otherConfigs_cores/1regular_ctl_otherF", show_effect=True)
# cth.plot_tree(features=columns, filename="output/robust_p_otherConfigs_cores/1honest_ctl_otherF", show_effect=True)
# cthv.plot_tree(features=columns, filename="output/robust_p_otherConfigs_cores/1valHonest_ctl_otherF", show_effect=True)

# ct_adaptive.plot_tree(features=columns, filename="output/otherConfigs_parallelism/parallelism_adaptive_ct_otherF", show_effect=True)
# ct_honest.plot_tree(features=columns, filename="output/otherConfigs_parallelism/parallelism_honest_ct_otherF", show_effect=True)
# ctl.plot_tree(features=columns, filename="output/otherConfigs_parallelism/parallelism_regular_ctl_otherF", show_effect=True)
# cth.plot_tree(features=columns, filename="output/otherConfigs_parallelism/parallelism_honest_ctl_otherF", show_effect=True)
# cthv.plot_tree(features=columns, filename="output/otherConfigs_parallelism/parallelism_valHonest_ctl_otherF", show_effect=True)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3723: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:254: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
cthv.get_variables_used(columns)
# Out:
# ['spark.executor.memory',
#  'spark.task.cpus',
#  'spark.default.parallelism',
#  'spark.serializer']

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(cthv_predict1, cthv_predict2)
# Out:
# 45949.303711373665
